# %%
import pandas as pd
import folium # pip install folium
import seaborn as sns # pip install seaborn
import matplotlib.pyplot as plt
import plotly.express as px # pip install plotly

from collections import Counter
# from keplergl import KeplerGl

plt.rc('font', family='Malgun Gothic') # 한글 폰트 설정 (Malgun Gothic)

plt.rc('axes', unicode_minus=False) # 마이너스 기호 깨짐 방지

# 공용 변수 선언
dataIn = './../dataIn/'
dataOut = './../dataOut/'

# %%
# 이미 생성해놓은 매장 정보 파일을 읽어옵니다.
starbucks = pd.read_csv(dataOut + 'starbucks_file.csv')
ediya = pd.read_csv(dataOut + 'ediya_file.csv')
hollysBefore = pd.read_csv(dataOut + 'hollys_file.csv')

# %%
print(f'스타벅스 매장 갯수 : {len(starbucks)}')
print(f'이디야 매장 갯수 : {len(ediya)}')
print(f'할리스 매장 갯수 : {len(hollysBefore)}')
# Out:
# 스타벅스 매장 갯수 : 666
# 이디야 매장 갯수 : 462
# 할리스 매장 갯수 : 40

# %%
starbucks.columns
# Out:
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
ediya.columns
# Out:
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
hollysBefore.columns
# Out:
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도', '전화 번호', '24시간', 'DT 매장',
#        '주차', '테라스', '흡연시설'],
#       dtype='object')

# %%
print('스타벅스와 할리스의 공통 컬럼 정보')
common_col = starbucks.columns.intersection(hollysBefore.columns)
common_col
# Out:
# 스타벅스와 할리스의 공통 컬럼 정보
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
print('다른 매장들과 공통된 컬럼들만 따로 추출')
hollys = hollysBefore[common_col]
hollys.columns
# Out:
# 다른 매장들과 공통된 컬럼들만 따로 추출
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
print('# 각 매장의 데이터 프레임을 하나로 모아줌')
coffeeFrame = pd.concat([starbucks,ediya, hollys],axis=0)
print(f'전체 매장 갯수 : {len(coffeeFrame)}')
# Out:
# # 각 매장의 데이터 프레임을 하나로 모아줌
# 전체 매장 갯수 : 1168

# %%
filename = dataOut + 'coffee_list.csv'
coffeeFrame.to_csv(filename, index=False, encoding='UTF-8')
print(f'{filename} 파일이 저장되었습니다.')
# Out:
# ./../dataOut/coffee_list.csv 파일이 저장되었습니다.

# %%
coffeeFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1168 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   브랜드     1168 non-null   object
#  1   상호      1168 non-null   object
#  2   주소      1168 non-null   object
#  3   시도      1168 non-null   object
#  4   군구      1168 non-null   object
#  5   위도      1166 non-null   float64
#  6   경도      1166 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 73.0+ KB

# %%
print(f'위도/경도 결측치 제거전 : {len(coffeeFrame)}')
# Out:
# 위도/경도 결측치 제거전 : 1168

# %%
# notnull() 함수는 결측치가 아니면 True를 반환해주는 함수 ↔ isnull()
mapFrame = coffeeFrame[coffeeFrame['위도'].notnull()]
print(f'위도/경도 결측치 제거후 : {len(mapFrame)}')
# Out:
# 위도/경도 결측치 제거후 : 1166

# %%
# 지도 위에 매장 표시
# folium에서 사용할 브랜드 별 색상지정
brand_colors = {
    '스타벅스':'beige',
    '이디야':'darkblue',
    '할리스':'lightblue'
}

seoul_center = [mapFrame['위도'].mean(), mapFrame['경도'].mean()] # 서울 중심 위치
seoul_center
# Out:
# [np.float64(37.54322478480824), np.float64(126.98812735399429)]

# %%
# 서울 지도 객체
seoul_map = folium.Map(location=seoul_center, zoom_start=11)

# iterrows() : iterable rows(전체 행을 반복)
# for 색인_번호, 데이터_1행 in mapFrame.iterrows():
# 찾아 볼것 : 마커 크기 조정, popup의 모양
for _,row in mapFrame.iterrows():
    folium.Marker(
        location=[row['위도'],row['경도']],
        popup=f"{row['상호']}({row['브랜드']})", # 팝업 예시 : xxx점(스타벅스)
        icon=folium.Icon(color=brand_colors.get(row['브랜드'],'gray'))
    ).add_to(seoul_map)
#end for

htmlfile = dataOut + 'coffee_map.html'
seoul_map.save(htmlfile)
print(f'{htmlfile} 파일 생성')
# Out:
# ./../dataOut/coffee_map.html 파일 생성

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1ddab52e45d653087f31dfe574758d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1ddab52e45d653087f31dfe574758d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1ddab52e45d653087f31dfe574758d2 = L.map(
#                 &quot;map_c1ddab52e45d653087f31dfe574758d2&quot;,
#                 {
#                     center: [37.54322478480824, 126.98812735399429],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_026aab93cc179ee66b5b02cf616ae873 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_026aab93cc179ee66b5b02cf616ae873.addTo(map_c1ddab52e45d653087f31dfe574758d2);
#
#
#             var marker_002a6b1a1aedaba3dc889f7c5657dfdc = L.marker(
#                 [37.501087, 127.043069],
#                 {
# }
#             ).addTo(map_c1ddab52e45d653087f31dfe574758d2);
#
#
#             var icon_96276dd6721f0ae9ecdf1541ff742e20 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_03fa3810d5ea6d2aff2b091bf250fdc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_184958f528219b7f31a57e891d727665 = $(`&lt;div id=&quot;html_184958f528219b7f31a57e891d727665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;리저브 매장 2번(스타벅스)&lt;/div&gt;`)[0];
#                 popup_03fa3810d5ea6d2aff2b091bf250fdc0.setContent(html_184958f528219b7f31a57e891d727665);
#
#
#
#         marker_002a6b1a1aedaba3dc889f7c5657dfdc.bindPopup(popup_03fa3810d5ea6d2aff2b091bf250fdc0)
#         ;
#
#
#
#
#                 marker_002a6b1a1aedaba3dc889f7c5657dfdc.setIcon(icon_96276dd6721f0ae9ecdf1541ff742e20);
#
#
#             var marker_cf2ecbf3e9418302120046f9b4b54f1b = L.marker(
#                 [37.510178, 127.022223],
#                 {
# }
#             ).addTo(map_c1ddab52e45d653087f31dfe574758d2);
#
#
#             var icon_b69138236fb0eaebb8870257716891b3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29ae3531f7bbdba04046d4da371771db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa99dc9607c84cbb0e2c5ed15e981f68 = $(`&lt;div id=&quot;html_aa99dc9607c84cbb0e2c5ed15e981f68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;리저브 매장 2번(스타벅스)&lt;/div&gt;`)[0];
#                 popup_29ae3531f7bbdba04046d4da371771db.setContent(html_aa99dc9607c84cbb0e2c5ed15e981f68);
#
#
#
#         marker_cf2ecbf3e9418302120046f9b4b54f1b.bindPopup(popup_29ae3531f7bbdba04046d4da371771db)
#         ;
#
#
#
#
#                 marker_cf2ecbf3e9418302120046f9b4b54f1b.setIcon(icon_b69138236fb0eaebb8870257716891b3);
#
#
#             var marker_c902648efdd1e2d54a39809bcf130805 = L.marker(
#                 [37.5139309, 127.0206057],
#                 {
# }
#             ).addTo(map_c1ddab52e45d653087f31dfe574758d2);
#
#
#             var icon_d400ad0b280277f8bd3263708aec472c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e8610a1eb5a6ef4e0595dc717b74da1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f3bf4dfde4e789379abba50d9894e60 = $(`&lt;div id=&quot;html_9f3bf4dfde4e789379abba50d9894e60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;리저브 매장 2번(스타벅스)&lt;/div&gt;`)[0];
#                 popup_e8610a1eb5a6ef4e0595dc717b74da1e.setContent(html_9f3bf4dfde4e789379abba50d9894e60);
#
#
#
#         marker_c902648efdd1e2d54a39809bcf130805.bindPopup(popup_e8610a1eb5a6ef4e0595dc717b74da1e)
#         ;
#
#
#
#
#                 marker_c902648efdd1e2d54a39809bcf130805.setIcon(icon_d400ad0b280277f8bd3263708aec472c);
#
#
#             v

# %%
print('# 군구 컬럼이 마포구, 용산구, 서대문구인 항목들만 추출')
concern_gu = ['마포구', '용산구', '서대문구']
myfilter01 = mapFrame[mapFrame['군구'].isin(concern_gu)]
print(f'갯수 : {len(myfilter01)}')
# Out:
# # 군구 컬럼이 마포구, 용산구, 서대문구인 항목들만 추출
# 갯수 : 140

# %%
myfilter01.head()
# Out:
#       브랜드         상호                           주소     시도   군구         위도  \
# 224  스타벅스  리저브 매장 2번       서울특별시 마포구 백범로 35 (신수동)  서울특별시  마포구  37.551027
# 225  스타벅스  리저브 매장 2번      서울특별시 마포구 상암산로 76 (상암동)  서울특별시  마포구  37.579314
# 226  스타벅스  리저브 매장 2번      서울특별시 마포구 토정로 295 (용강동)  서울특별시  마포구  37.541186
# 227  스타벅스  리저브 매장 2번      서울특별시 마포구 양화로 125 (서교동)  서울특별시  마포구  37.554636
# 228  스타벅스  리저브 매장 2번  서울특별시 마포구 마포대로 173-14 (아현동)  서울특별시  마포구  37.550800
#
#              경도
# 224  126.943134
# 225  126.892210
# 226  126.942209
# 227  126.920360
# 228  126.953432

# %%
my_center = [myfilter01['위도'].mean(), myfilter01['경도'].mean()] # 서울 중심 위치
my_center
# Out:
# [np.float64(37.55298409211924), np.float64(126.9430383047872)]

# %%
# 서울 지도 객체
filter_map = folium.Map(location=my_center, zoom_start=13, tiles='OpenStreetMap')

# iterrows() : iterable rows(전체 행을 반복)
# for 색인_번호, 데이터_1행 in mapFrame.iterrows():
# 찾아 볼것 : 마커 크기 조정, popup의 모양
for _,row in myfilter01.iterrows():
    # 브랜드 별로 색상을 다르게 지정하려면 brand_colors에 추가하는 방법도 있음.
    ic_color = 'white' # 아이콘 색상
    folium.Marker(
        location=[row['위도'],row['경도']],
        popup=row['주소'],
        tooltip=f"{row['상호']}({row['브랜드']})", # 팝업 예시 : xxx점(스타벅스)
        icon=folium.Icon(
            color=brand_colors.get(row['브랜드'],'gray'),
        icon_color='ic_color',
        icon='coffee',
        prefix='fa')
    ).add_to(filter_map)
#end for

htmlfile = dataOut + 'coffee_map02.html'
seoul_map.save(htmlfile)
print(f'{htmlfile} 파일 생성')
# Out:
# ./../dataOut/coffee_map02.html 파일 생성

# %%
filter_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_519067a78df681e349c72dbc6e70f38b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_519067a78df681e349c72dbc6e70f38b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_519067a78df681e349c72dbc6e70f38b = L.map(
#                 &quot;map_519067a78df681e349c72dbc6e70f38b&quot;,
#                 {
#                     center: [37.55298409211924, 126.9430383047872],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6581bdd840cbd8c52a6c33055a19449d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6581bdd840cbd8c52a6c33055a19449d.addTo(map_519067a78df681e349c72dbc6e70f38b);
#
#
#             var marker_7a23275b1328df827cb1a38c9a2220f6 = L.marker(
#                 [37.55102696988243, 126.94313374835716],
#                 {
# }
#             ).addTo(map_519067a78df681e349c72dbc6e70f38b);
#
#
#             var icon_8e7c3b45dade3b5abd671f9845c49d4d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;ic_color&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4072d4b4be60a2385dfef9afe8eeb171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8a7c01fc2c82a0c69ad243a12a5d0bd = $(`&lt;div id=&quot;html_f8a7c01fc2c82a0c69ad243a12a5d0bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 마포구 백범로 35 (신수동)&lt;/div&gt;`)[0];
#                 popup_4072d4b4be60a2385dfef9afe8eeb171.setContent(html_f8a7c01fc2c82a0c69ad243a12a5d0bd);
#
#
#
#         marker_7a23275b1328df827cb1a38c9a2220f6.bindPopup(popup_4072d4b4be60a2385dfef9afe8eeb171)
#         ;
#
#
#
#
#             marker_7a23275b1328df827cb1a38c9a2220f6.bindTooltip(
#                 `&lt;div&gt;
#                      리저브 매장 2번(스타벅스)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7a23275b1328df827cb1a38c9a2220f6.setIcon(icon_8e7c3b45dade3b5abd671f9845c49d4d);
#
#
#             var marker_de590703ae832199efd0fbbd91aef3d2 = L.marker(
#                 [37.57931426554629, 126.89221044590168],
#                 {
# }
#             ).addTo(map_519067a78df681e349c72dbc6e70f38b);
#
#
#             var icon_218af356aaff91935519a713906980fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;ic_color&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_379dea486c42bff4fe015c87645ccc79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f9cafb372c3e69bbb339bc80ef3f89b = $(`&lt;div id=&quot;html_1f9cafb372c3e69bbb339bc80ef3f89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 마포구 상암산로 76 (상암동)&lt;/div&gt;`)[0];
#                 popup_379dea486c42bff4fe015c87645ccc79.setContent(html_1f9cafb372c3e69bbb339bc80ef3f89b);
#
#
#
#         marker_de590703ae832199efd0fbbd91aef3d2.bindPopup(popup_379dea486c42bff4fe015c87645ccc79)
#         ;
#
#
#
#
#             marker_de590703ae832199efd0fbbd91aef3d2.bindTooltip(
#                 `&lt;div&gt;
#                      리저브 매장 2번(스타벅스)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_de590703ae832199efd0fbbd91aef3d2.setIcon(icon_218af356aaff91935519a713906980fb);
#
#
#             var marker_eeaecc10fdae47dea19a49f490960586 = L.marker(
#                 [37.541186, 126.942209],
#                 {
# }
#             ).addTo(map_519067a78df681e349c72dbc6e70f38b);
#
#
#             var icon_6d6c46bebf06aea58bf147ce635fd46f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;ic_color&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d638640b55663a76f53d64ac1fe84bec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_894d529104eb4f3ca55e36694b23e29b = $(`&lt;div id=&quot;html_894d529104eb4f
